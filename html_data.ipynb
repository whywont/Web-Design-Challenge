# %%
import pandas as pd

# %%
html_df = pd.read_csv('weather_data/cities.csv')
html_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        ushuaia -54.8000  -68.3000      8.81        53          20
# 1        rikitea -23.1203 -134.9692     23.64        74          34
# 2           yaan   7.3833    8.5667     23.73        89          97
# 3    port alfred -33.5906   26.8910     19.38        83         100
# 4  batagay-alyta  67.8006  130.4114    -15.98        93         100
#
#    Wind Speed Country        Date
# 0        5.66      AR  1635380943
# 1        1.51      PF  1635380891
# 2        2.65      NG  1635380944
# 3       11.68      ZA  1635380944
# 4        0.20      RU  1635380945

# %%
html_df_drop = html_df.drop(columns = ['Date'])

# %%
html = html_df_drop.to_html()
print(html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>ushuaia</td>
#       <td>-54.8000</td>
#       <td>-68.3000</td>
#       <td>8.81</td>
#       <td>53</td>
#       <td>20</td>
#       <td>5.66</td>
#       <td>AR</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rikitea</td>
#       <td>-23.1203</td>
#       <td>-134.9692</td>
#       <td>23.64</td>
#       <td>74</td>
#       <td>34</td>
#       <td>1.51</td>
#       <td>PF</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>yaan</td>
#       <td>7.3833</td>
#       <td>8.5667</td>
#       <td>23.73</td>
#       <td>89</td>
#       <td>97</td>
#       <td>2.65</td>
#       <td>NG</td>
# ...
